# %%
# Load ckpt
import torch

ckpt_path = '/work/yuchi/stanford/spring-2025/cs231n/cs231n-final-project/3D-Diffusion-Policy/data/outputs/baseline/checkpoints/latest.ckpt'

ckpt = torch.load(ckpt_path)
# Out:
# /tmp/ipykernel_870135/4185553786.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(ckpt_path)

# %%
for key in ckpt['state_dicts']['model'].keys():
    print(key)
# Out:
# _dummy_variable
# obs_encoder.extractor.mlp.0.weight
# obs_encoder.extractor.mlp.0.bias
# obs_encoder.extractor.mlp.1.weight
# obs_encoder.extractor.mlp.1.bias
# obs_encoder.extractor.mlp.3.weight
# obs_encoder.extractor.mlp.3.bias
# obs_encoder.extractor.mlp.4.weight
# obs_encoder.extractor.mlp.4.bias
# obs_encoder.extractor.mlp.6.weight
# obs_encoder.extractor.mlp.6.bias
# obs_encoder.extractor.mlp.7.weight
# obs_encoder.extractor.mlp.7.bias
# obs_encoder.extractor.final_projection.0.weight
# obs_encoder.extractor.final_projection.0.bias
# obs_encoder.extractor.final_projection.1.weight
# obs_encoder.extractor.final_projection.1.bias
# obs_encoder.state_mlp.0.weight
# obs_encoder.state_mlp.0.bias
# obs_encoder.state_mlp.2.weight
# obs_encoder.state_mlp.2.bias
# model.mid_modules.0.blocks.0.block.0.weight
# model.mid_modules.0.blocks.0.block.0.bias
# model.mid_modules.0.blocks.0.block.1.weight
# model.mid_modules.0.blocks.0.block.1.bias
# model.mid_modules.0.blocks.1.block.0.weight
# ...
